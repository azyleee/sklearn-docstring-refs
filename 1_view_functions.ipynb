# %%
import pickle
import pandas as pd
import os
from docstring_refs import count_mentions_from_url

def read_to_df(pkl_path):
    with open(pkl_path, 'rb') as file:
        d = pickle.load(file)
    df = pd.DataFrame.from_dict(d, orient='index')
    df = df.rename_axis('function')
    df = df.reset_index()
    filename = pkl_path.replace('.pkl','.xlsx')
    df.to_excel(filename, index=False)
    return df

# %%
functions_df = read_to_df('functions_info.pkl')
functions_df['example_files'] = functions_df['example_files'].apply(lambda L: [s.replace('\\','/') for s in L])
functions_df['path'] = functions_df['path'].apply(lambda s: s.replace('\\','/'))
functions_df.to_excel('functions_info.xlsx', index=False)

functions_df

# for each example file, get the associated functions
functions_df_exploded = functions_df.explode('example_files')
examples_df = functions_df.explode('example_files').groupby('example_files')[['function', 'path']].agg(list).reset_index()

# get the name of the example and the number of mentions. If number of mentions==1, then nobody has started working on it
examples_df['example_filename'] = examples_df['example_files'].apply(os.path.basename)
examples_df['example'] = examples_df['example_filename'].apply(lambda s: os.path.splitext(s)[0])
examples_df['mentions'] = examples_df['example'].apply(count_mentions_from_url)

examples_df
# Out:
#                                          example_files  \
# 0    ../scikit-learn/examples/applications/plot_cyc...
# 1    ../scikit-learn/examples/applications/plot_dig...
# 2    ../scikit-learn/examples/applications/plot_fac...
# 3    ../scikit-learn/examples/applications/plot_mod...
# 4    ../scikit-learn/examples/applications/plot_out...
# ..                                                 ...
# 198  ../scikit-learn/examples/text/plot_document_cl...
# 199  ../scikit-learn/examples/text/plot_hashing_vs_...
# 200  ../scikit-learn/examples/tree/plot_cost_comple...
# 201     ../scikit-learn/examples/tree/plot_iris_dtc.py
# 202  ../scikit-learn/examples/tree/plot_unveil_tree...
#
#                                           function  \
# 0    [make_pipeline, fetch_openml, cross_validate]
# 1                 [fetch_openml, train_test_split]
# 2        [classification_report, train_test_split]
# 3                               [train_test_split]
# 4                                  [get_data_home]
# ..                                             ...
# 198            [make_pipeline, fetch_20newsgroups]
# 199                           [fetch_20newsgroups]
# 200         [load_breast_cancer, train_test_split]
# 201                                    [plot_tree]
# 202                             [train_test_split]
#
#                                                   path  \
# 0    [../scikit-learn/sklearn/pipeline.py, ../sciki...
# 1    [../scikit-learn/sklearn/datasets/_openml.py, ...
# 2    [../scikit-learn/sklearn/metrics/_classificati...
# 3    [../scikit-learn/sklearn/model_selection/_spli...
# 4          [../scikit-learn/sklearn/datasets/_base.py]
# ..                                                 ...
# 198  [../scikit-learn/sklearn/pipeline.py, ../sciki...
# 199  [../scikit-learn/sklearn/datasets/_twenty_news...
# 200  [../scikit-learn/sklearn/datasets/_base.py, .....
# 201          [../scikit-learn/sklearn/tree/_export.py]
# 202  [../scikit-learn/sklearn/model_selection/_spli...
#
#                          example_filename                            example  \
# 0    plot_cyclical_feature_engineering.py  plot_cyclical_feature_engineering
# 1                plot_digits_denoising.py              plot_digits_denoising
# 2                plot_face_recognition.py              plot_face_recognition
# 3      plot_model_complexity_influence.py    plot_model_complexity_influence
# 4      plot_out_of_core_classification.py    plot_out_of_core_classification
# ..                                    ...                                ...
# 198           plot_document_clustering.py           plot_document_clustering
# 199    plot_hashing_vs_dict_vectorizer.py    plot_hashing_vs_dict_vectorizer
# 200       plot_cost_complexity_pruning.py       plot_cost_complexity_pruning
# 201                      plot_iris_dtc.py                      plot_iris_dtc
# 202         plot_unveil_tree_structure.py         plot_unveil_tree_structure
#
#      mentions
# 0           2
# 1           2
# 2           1
# 3           1
# 4           1
# ..        ...
# 198         3
# 199         2
# 200         2
# 201         1
# 202         1
#
# [203 rows x 6 columns]

# %%
exaples_to_own = examples_df[examples_df['mentions']==1]
exaples_to_own.to_excel('examples_not_wip.xlsx', index=False)
exaples_to_own
# Out:
#                                          example_files  \
# 2    ../scikit-learn/examples/applications/plot_fac...
# 3    ../scikit-learn/examples/applications/plot_mod...
# 4    ../scikit-learn/examples/applications/plot_out...
# 5    ../scikit-learn/examples/applications/plot_out...
# 10   ../scikit-learn/examples/applications/wikipedi...
# ..                                                 ...
# 191  ../scikit-learn/examples/svm/plot_linearsvc_su...
# 193  ../scikit-learn/examples/svm/plot_separating_h...
# 194     ../scikit-learn/examples/svm/plot_svm_anova.py
# 201     ../scikit-learn/examples/tree/plot_iris_dtc.py
# 202  ../scikit-learn/examples/tree/plot_unveil_tree...
#
#                                       function  \
# 2    [classification_report, train_test_split]
# 3                           [train_test_split]
# 4                              [get_data_home]
# 5                                  [load_wine]
# 10                            [randomized_svd]
# ..                                         ...
# 191                               [make_blobs]
# 193                               [make_blobs]
# 194                          [cross_val_score]
# 201                                [plot_tree]
# 202                         [train_test_split]
#
#                                                   path  \
# 2    [../scikit-learn/sklearn/metrics/_classificati...
# 3    [../scikit-learn/sklearn/model_selection/_spli...
# 4          [../scikit-learn/sklearn/datasets/_base.py]
# 5          [../scikit-learn/sklearn/datasets/_base.py]
# 10          [../scikit-learn/sklearn/utils/extmath.py]
# ..                                                 ...
# 191  [../scikit-learn/sklearn/datasets/_samples_gen...
# 193  [../scikit-learn/sklearn/datasets/_samples_gen...
# 194  [../scikit-learn/sklearn/model_selection/_vali...
# 201          [../scikit-learn/sklearn/tree/_export.py]
# 202  [../scikit-learn/sklearn/model_selection/_spli...
#
#                              example_filename  \
# 2                    plot_face_recognition.py
# 3          plot_model_complexity_influence.py
# 4          plot_out_of_core_classification.py
# 5              plot_outlier_detection_wine.py
# 10         wikipedia_principal_eigenvector.py
# ..                                        ...
# 191         plot_linearsvc_support_vectors.py
# 193  plot_separating_hyperplane_unbalanced.py
# 194                         plot_svm_anova.py
# 201                          plot_iris_dtc.py
# 202             plot_unveil_tree_structure.py
#
#                                    example  mentions
# 2                    plot_face_recognition         1
# 3          plot_model_complexity_influence         1
# 4          plot_out_of_core_classification         1
# 5              plot_outlier_detection_wine         1
# 10         wikipedia_principal_eigenvector         1
# ..                                     ...       ...
# 191         plot_linearsvc_support_vectors         1
# 193  plot_separating_hyperplane_unbalanced         1
# 194                         plot_svm_anova         1
# 201                          plot_iris_dtc         1
# 202             plot_unveil_tree_structure         1
#
# [129 rows x 6 columns]

# %%
referenced_df = read_to_df('referenced_info.pkl')
